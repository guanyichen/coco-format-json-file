# %% [markdown]
# # COCO Image Viewer
# This notebook will allow you to view details about a COCO dataset and preview segmentations on annotated images.
# Learn more about it at: http://cocodataset.org/

# %%
import IPython
import os
import json
import random
import numpy as np
import requests
from io import BytesIO
from math import trunc
from PIL import Image as PILImage
from PIL import ImageDraw as PILImageDraw

# %%
# Load the dataset json
class CocoDataset():
    def __init__(self, annotation_path, image_dir):
        self.annotation_path = annotation_path
        self.image_dir = image_dir
        self.colors = ['blue', 'purple', 'red', 'green', 'orange', 'salmon', 'pink', 'gold',
                       'orchid', 'slateblue', 'limegreen', 'seagreen', 'darkgreen', 'olive',
                       'teal', 'aquamarine', 'steelblue', 'powderblue', 'dodgerblue', 'navy',
                       'magenta', 'sienna', 'maroon']

        json_file = open(self.annotation_path)
        self.coco = json.load(json_file)
        json_file.close()

        self.process_info()
        self.process_licenses()
        self.process_categories()
        self.process_images()
        self.process_segmentations()

    def display_info(self):
        print('Dataset Info:')
        print('=============')
        if self.info is None:
            return
        for key, item in self.info.items():
            print('  {}: {}'.format(key, item))

        requirements = [['description', str],
                        ['url', str],
                        ['version', str],
                        ['year', int],
                        ['contributor', str],
                        ['date_created', str]]
        for req, req_type in requirements:
            if req not in self.info:
                print('ERROR: {} is missing'.format(req))
            elif type(self.info[req]) != req_type:
                print('ERROR: {} should be type {}'.format(req, str(req_type)))
        print('')

    def display_licenses(self):
        print('Licenses:')
        print('=========')

        if self.licenses is None:
            return
        requirements = [['id', int],
                        ['url', str],
                        ['name', str]]
        for license in self.licenses:
            for key, item in license.items():
                print('  {}: {}'.format(key, item))
            for req, req_type in requirements:
                if req not in license:
                    print('ERROR: {} is missing'.format(req))
                elif type(license[req]) != req_type:
                    print('ERROR: {} should be type {}'.format(
                        req, str(req_type)))
            print('')
        print('')

    def display_categories(self):
        print('Categories:')
        print('=========')
        for sc_key, sc_val in self.super_categories.items():
            print('  super_category: {}'.format(sc_key))
            for cat_id in sc_val:
                print('    id {}: {}'.format(
                    cat_id, self.categories[cat_id]['name']))
            print('')

    def display_image(self, image_id, show_polys=True, show_bbox=True, show_crowds=True, use_url=False):
        print('Image:')
        print('======')
        if image_id == 'random':
            image_id = random.choice(list(self.images.keys()))

        # Print the image info
        image = self.images[image_id]
        for key, val in image.items():
            print('  {}: {}'.format(key, val))

        # Open the image
        if use_url:
            image_path = image['coco_url']
            response = requests.get(image_path)
            image = PILImage.open(BytesIO(response.content))

        else:
            # image_path = os.path.join(self.image_dir, image['file_name'])
            image_path = "{}/{}".format(self.image_dir, image['file_name'])
            image = PILImage.open(image_path)

        # Calculate the size and adjusted display size
        max_width = 600
        image_width, image_height = image.size
        adjusted_width = min(image_width, max_width)
        adjusted_ratio = adjusted_width / image_width
        adjusted_height = adjusted_ratio * image_height

        # Create list of polygons to be drawn
        polygons = {}
        bbox_polygons = {}
        rle_regions = {}
        poly_colors = {}
        bbox_categories = {}
        print('  segmentations ({}):'.format(
            len(self.segmentations[image_id])))
        for i, segm in enumerate(self.segmentations[image_id]):
            polygons_list = []
            if segm['iscrowd'] != 0:
                # Gotta decode the RLE
                px = 0
                x, y = 0, 0
                rle_list = []
                for j, counts in enumerate(segm['segmentation']['counts']):
                    if j % 2 == 0:
                        # Empty pixels
                        px += counts
                    else:
                        # Need to draw on these pixels, since we are drawing in vector form,
                        # we need to draw horizontal lines on the image
                        x_start = trunc(
                            trunc(px / image_height) * adjusted_ratio)
                        y_start = trunc(px % image_height * adjusted_ratio)
                        px += counts
                        x_end = trunc(trunc(px / image_height)
                                      * adjusted_ratio)
                        y_end = trunc(px % image_height * adjusted_ratio)
                        if x_end == x_start:
                            # This is only on one line
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (y_end - y_start)})
                        if x_end > x_start:
                            # This spans more than one line
                            # Insert top line first
                            rle_list.append(
                                {'x': x_start, 'y': y_start, 'width': 1, 'height': (image_height - y_start)})

                            # Insert middle lines if needed
                            lines_spanned = x_end - x_start + 1  # total number of lines spanned
                            full_lines_to_insert = lines_spanned - 2
                            if full_lines_to_insert > 0:
                                full_lines_to_insert = trunc(
                                    full_lines_to_insert * adjusted_ratio)
                                rle_list.append(
                                    {'x': (x_start + 1), 'y': 0, 'width': full_lines_to_insert, 'height': image_height})

                            # Insert bottom line
                            rle_list.append(
                                {'x': x_end, 'y': 0, 'width': 1, 'height': y_end})
                if len(rle_list) > 0:
                    rle_regions[segm['id']] = rle_list
            else:
                # Add the polygon segmentation
                for segmentation_points in segm['segmentation']:
                    segmentation_points = np.multiply(
                        segmentation_points, adjusted_ratio).astype(int)
                    polygons_list.append(
                        str(segmentation_points).lstrip('[').rstrip(']'))
            polygons[segm['id']] = polygons_list
            if i < len(self.colors):
                poly_colors[segm['id']] = self.colors[i]
            else:
                poly_colors[segm['id']] = 'white'

            bbox = segm['bbox']
            bbox_points = [bbox[0], bbox[1], bbox[0] + bbox[2], bbox[1],
                           bbox[0] + bbox[2], bbox[1] +
                           bbox[3], bbox[0], bbox[1] + bbox[3],
                           bbox[0], bbox[1]]
            bbox_points = np.multiply(bbox_points, adjusted_ratio).astype(int)
            bbox_polygons[segm['id']] = str(
                bbox_points).lstrip('[').rstrip(']')
            bbox_categories[segm['id']] = self.categories[segm['category_id']]
            # Print details
            print('    {}:{}:{}'.format(
                segm['id'], poly_colors[segm['id']], self.categories[segm['category_id']]))

        # Draw segmentation polygons on image
        html = '<div class="container" style="position:relative;">'
        html += '<img src="{}" style="position:relative;top:0px;left:0px;width:{}px;">'.format(
            image_path, adjusted_width)
        html += '<div class="svgclass"><svg width="{}" height="{}">'.format(
            adjusted_width, adjusted_height)

        if show_polys:
            for seg_id, points_list in polygons.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for points in points_list:
                    html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5" />'.format(
                        points, fill_color, stroke_color)

        if show_crowds:
            for seg_id, rect_list in rle_regions.items():
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                for rect_def in rect_list:
                    x, y = rect_def['x'], rect_def['y']
                    w, h = rect_def['width'], rect_def['height']
                    html += '<rect x="{}" y="{}" width="{}" height="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0.5; stroke-opacity:0.5" />'.format(
                        x, y, w, h, fill_color, stroke_color)

        if show_bbox:
            for seg_id, points in bbox_polygons.items():
                x, y = [int(i) for i in points.split()[:2]]
                html += '<text x="{}" y="{}" fill="yellow">{}</text>'.format(
                    x, y, bbox_categories[seg_id]["name"])
                fill_color = poly_colors[seg_id]
                stroke_color = poly_colors[seg_id]
                html += '<polygon points="{}" style="fill:{}; stroke:{}; stroke-width:1; fill-opacity:0" />'.format(
                    points, fill_color, stroke_color)

        html += '</svg></div>'
        html += '</div>'
        html += '<style>'
        html += '.svgclass { position:absolute; top:0px; left:0px;}'
        html += '</style>'
        return html

    def process_info(self):
        self.info = self.coco.get('info')

    def process_licenses(self):
        self.licenses = self.coco.get('licenses')

    def process_categories(self):
        self.categories = {}
        self.super_categories = {}
        for category in self.coco['categories']:
            cat_id = category['id']
            super_category = category['supercategory']

            # Add category to the categories dict
            if cat_id not in self.categories:
                self.categories[cat_id] = category
            else:
                print("ERROR: Skipping duplicate category id: {}".format(category))

            # Add category to super_categories dict
            if super_category not in self.super_categories:
                # Create a new set with the category id
                self.super_categories[super_category] = {cat_id}
            else:
                self.super_categories[super_category] |= {
                    cat_id}  # Add category id to the set

    def process_images(self):
        self.images = {}
        for image in self.coco['images']:
            image_id = image['id']
            if image_id in self.images:
                print("ERROR: Skipping duplicate image id: {}".format(image))
            else:
                self.images[image_id] = image

    def process_segmentations(self):
        self.segmentations = {}
        for segmentation in self.coco['annotations']:
            image_id = segmentation['image_id']
            if image_id not in self.segmentations:
                self.segmentations[image_id] = []
            self.segmentations[image_id].append(segmentation)

# %%
annotation_path = "roadscene_train.json"
image_dir = "roadscene_train"

coco_dataset = CocoDataset(annotation_path, image_dir)
coco_dataset.display_info()
coco_dataset.display_licenses()
coco_dataset.display_categories()
# Out:
# Dataset Info:
# =============
# Licenses:
# =========
# Categories:
# =========
#   super_category: car
#     id 0: car
#
#   super_category: dashedline
#     id 1: dashedline
#
#   super_category: midlane
#     id 2: midlane
#
#   super_category: pothole
#     id 3: pothole
#
#   super_category: rightlane
#     id 4: rightlane

# %%
for k, v in coco_dataset.images.items():
    print(k, v)
# Out:
# 0 {'height': 720, 'width': 1280, 'id': 0, 'file_name': 'img053.jpg'}
# 1 {'height': 720, 'width': 1280, 'id': 1, 'file_name': 'img103.jpg'}
# 2 {'height': 720, 'width': 1280, 'id': 2, 'file_name': 'img032.jpg'}
# 3 {'height': 720, 'width': 1280, 'id': 3, 'file_name': 'img125.jpg'}
# 4 {'height': 720, 'width': 1280, 'id': 4, 'file_name': 'img136.jpg'}
# 5 {'height': 720, 'width': 1280, 'id': 5, 'file_name': 'img098.jpg'}
# 6 {'height': 720, 'width': 1280, 'id': 6, 'file_name': 'img111.jpg'}
# 7 {'height': 720, 'width': 1280, 'id': 7, 'file_name': 'img078.jpg'}
# 8 {'height': 720, 'width': 1280, 'id': 8, 'file_name': 'img093.jpg'}
# 9 {'height': 720, 'width': 1280, 'id': 9, 'file_name': 'img022.jpg'}
# 10 {'height': 720, 'width': 1280, 'id': 10, 'file_name': 'img018.jpg'}
# 11 {'height': 720, 'width': 1280, 'id': 11, 'file_name': 'img122.jpg'}
# 12 {'height': 720, 'width': 1280, 'id': 12, 'file_name': 'img049.jpg'}
# 13 {'height': 720, 'width': 1280, 'id': 13, 'file_name': 'img054.jpg'}
# 14 {'height': 720, 'width': 1280, 'id': 14, 'file_name': 'img057.jpg'}
# 15 {'height': 720, 'width': 1280, 'id': 15, 'file_name': 'img105.jpg'}
# 16 {'height': 720, 'width': 1280, 'id': 16, 'file_name': 'img025.jpg'}
# 17 {'height': 720, 'width': 1280, 'id': 17, 'file_name': 'img086.jpg'}
# 18 {'height': 720, 'width': 1280, 'id': 18, 'file_name': 'img033.jpg'}
# 19 {'height': 720, 'width': 1280, 'id': 19, 'file_name': 'img005.jpg'}
# 20 {'height': 720, 'width': 1280, 'id': 20, 'file_name': 'img108.jpg'}
# 21 {'height': 720, 'width': 1280, 'id': 21, 'file_name': 'img024.jpg'}
# 22 {'height': 720, 'width': 1280, 'id': 22, 'file_name': 'img013.jpg'}
# 23 {'height': 720, 'width': 1280, 'id': 23, 'file_name': 'img102.jpg'}
# 24 {'height': 720, 'width': 1280, 'id': 24, 'file_name': 'img014.jpg'}
# 25 {'height': 720, 'width': 1280, 'id': 25, 'file_name': 'img107.jpg'}
# 26 {'height': 720, 'width': 1280, 'id': 26, 'file_name': 'img030.jpg'}
# 27 {'height': 720, 'width': 1280, 'id': 27, 'file_name': 'img123.jpg'}
# 28 {'height': 720, 'width': 1280, 'id': 28, 'file_name': 'img113.jpg'}
# 29 {'height': 720, 'width': 1280, 'id': 29, 'file_name': 'img051.jpg'}
# 30 {'height': 720, 'width': 1280, 'id': 30, 'file_name': 'img088.jpg'}
# 31 {'height': 720, 'width': 1280, 'id': 31, 'file_name': 'img031.jpg'}
# 32 {'height': 720, 'width': 1280, 'id': 32, 'file_name': 'img036.jpg'}
# 33 {'height': 720, 'width': 1280, 'id': 33, 'file_name': 'img117.jpg'}
# 34 {'height': 720, 'width': 1280, 'id': 34, 'file_name': 'img092.jpg'}
# 35 {'height': 720, 'width': 1280, 'id': 35, 'file_name': 'img042.jpg'}
# 36 {'height': 720, 'width': 1280, 'id': 36, 'file_name': 'img039.jpg'}
# 37 {'height': 720, 'width': 1280, 'id': 37, 'file_name': 'img109.jpg'}
# 38 {'height': 720, 'width': 1280, 'id': 38, 'file_name': 'img110.jpg'}
# 39 {'height': 720, 'width': 1280, 'id': 39, 'file_name': 'img085.jpg'}
# 40 {'height': 720, 'width': 1280, 'id': 40, 'file_name': 'img046.jpg'}
# 41 {'height': 720, 'width': 1280, 'id': 41, 'file_name': 'img120.jpg'}
# 42 {'height': 720, 'width': 1280, 'id': 42, 'file_name': 'img074.jpg'}
# 43 {'height': 720, 'width': 1280, 'id': 43, 'file_name': 'img087.jpg'}
# 44 {'height': 720, 'width': 1280, 'id': 44, 'file_name': 'img038.jpg'}
# 45 {'height': 720, 'width': 1280, 'id': 45, 'file_name': 'img012.jpg'}
# 46 {'height': 720, 'width': 1280, 'id': 46, 'file_name': 'img084.jpg'}
# 47 {'height': 720, 'width': 1280, 'id': 47, 'file_name': 'img029.jpg'}
# 48 {'height': 720, 'width': 1280, 'id': 48, 'file_name': 'img055.jpg'}
# 49 {'height': 720, 'width': 1280, 'id': 49, 'file_name': 'img043.jpg'}
# 50 {'height': 720, 'width': 1280, 'id': 50, 'file_name': 'img135.jpg'}
# 51 {'height': 720, 'width': 1280, 'id': 51, 'file_name': 'img044.jpg'}
# 52 {'height': 720, 'width': 1280, 'id': 52, 'file_name': 'img069.jpg'}
# 53 {'height': 720, 'width': 1280, 'id': 53, 'file_name': 'img080.jpg'}
# 54 {'height': 720, 'width': 1280, 'id': 54, 'file_name': 'img101.jpg'}
# 55 {'height': 720, 'width': 1280, 'id': 55, 'file_name': 'img134.jpg'}
# 56 {'height': 720, 'width': 1280, 'id': 56, 'file_name': 'img097.jpg'}
# 57 {'height': 720, 'width': 1280, 'id': 57, 'file_name': 'img096.jpg'}
# 58 {'height': 720, 'width': 1280, 'id': 58, 'file_name': 'img009.jpg'}
# 59 {'height': 720, 'width': 1280, 'id': 59, 'file_name': 'img121.jpg'}
# 60 {'height': 720, 'width': 1280, 'id': 60, 'file_name': 'img035.jpg'}
# 61 {'height': 720, 'width': 1280, 'id': 61, 'file_name': 'img061.jpg'}
# 62 {'height': 720, 'width': 1280, 'id': 62, 'file_name': 'img068.jpg'}
# 63 {'height': 720, 'width': 1280, 'id': 63, 'file_name': 'img132.jpg'}
# 64 {'height': 720, 'width': 1280, 'id': 64, 'file_name': 'img002.jpg'}
# 65 {'height': 720, 'width': 1280, 'id': 65, 'file_name': 'img090.jpg'}
# 66 {'height': 720, 'width': 1280, 'id': 66, 'file_name': 'img124.jpg'}
# 67 {'height': 720, 'width': 1280, 'id': 67, 'file_name': 'img026.jpg'}
# 68 {'height': 720, 'width': 1280, 'id': 68, 'file_name': 'img076.jpg'}
# 69 {'height': 720, 'width': 1280, 'id': 69, 'file_name': 'img130.jpg'}
# 70 {'height': 720, 'width': 1280, 'id': 70, 'file_name': 'img060.jpg'}
# 71 {'height': 720, 'width': 1280, 'id': 71, 'file_name': 'img027.jpg'}
# 72 {'height': 720, 'width': 1280, 'id': 72, 'file_name': 'img129.jpg'}
# 73 {'height': 720, 'width': 1280, 'id': 73, 'file_name': 'img099.jpg'}
# 74 {'height': 720, 'width': 1280, 'id': 74, 'file_name': 'img020.jpg'}
# 75 {'height': 720, 'width': 1280, 'id': 75, 'file_name': 'img116.jpg'}
# 76 {'height': 720, 'width': 1280, 'id': 76, 'file_name': 'img095.jpg'}
# 77 {'height': 720, 'width': 1280, 'id': 77, 'file_name': 'img104.jpg'}
# 78 {'height': 720, 'width': 1280, 'id': 78, 'file_name': 'img091.jpg'}
# 79 {'height': 720, 'width': 1280, 'id': 79, 'file_name': 'img016.jpg'}
# 80 {'height': 720, 'width': 1280, 'id': 80, 'file_name': 'img034.jpg'}
# 81 {'height': 720, 'width': 1280, 'id': 81, 'file_name': 'img006.jpg'}
# 82 {'height': 720, 'width': 1280, 'id': 82, 'file_name': 'img073.jpg'}
# 83 {'height': 720, 'width': 1280, 'id': 83, 'file_name': 'img058.jpg'}
# 84 {'height': 720, 'width': 1280, 'id': 84, 'file_name': 'img106.jpg'}
# 85 {'height': 720, 'width': 1280, 'id': 85, 'file_name': 'img127.jpg'}
# 86 {'height': 720, 'width': 1280, 'id': 86, 'file_name': 'img071.jpg'}
# 87 {'height': 720, 'width': 1280, 'id': 87, 'file_name': 'img004.jpg'}
# 88 {'height': 720, 'width': 1280, 'id': 88, 'file_name': 'img082.jpg'}
# 89 {'height': 720, 'width': 1280, 'id': 89, 'file_name': 'img112.jpg'}
# 90 {'height': 720, 'width': 1280, 'id': 90, 'file_name': 'img040.jpg'}
# 91 {'height': 720, 'width': 1280, 'id': 91, 'file_name': 'img079.jpg'}
# 92 {'height': 720, 'width': 1280, 'id': 92, 'file_name': 'img077.jpg'}
# 93 {'height': 720, 'width': 1280, 'id': 93, 'file_name': 'img048.jpg'}
# 94 {'height': 720, 'width': 1280, 'id': 94, 'file_name': 'img128.jpg'}
# 95 {'height': 720, 'width': 1280, 'id': 95, 'file_name': 'img131.jpg'}
# 96 {'height': 720, 'width': 1280, 'id': 96, 'file_name': 'img017.jpg'}
# 97 {'height': 720, 'width': 1280, 'id': 97, 'file_name': 'img070.jpg'}
# 98 {'height': 720, 'width': 1280, 'id': 98, 'file_name': 'img118.jpg'}
# 99 {'height': 720, 'width': 1280, 'id': 99, 'file_name': 'img015.jpg'}
# 100 {'height': 720, 'width': 1280, 'id': 100, 'file_name': 'img001.jpg'}
# 101 {'height': 720, 'width': 1280, 'id': 101, 'file_name': 'img081.jpg'}
# 102 {'height': 720, 'width': 1280, 'id': 102, 'file_name': 'img050.jpg'}
# 103 {'height': 720, 'width': 1280, 'id': 103, 'file_name': 'img062.jpg'}
# 104 {'height': 720, 'width': 1280, 'id': 104, 'file_name': 'img041.jpg'}
# 105 {'height': 720, 'width': 1280, 'id': 105, 'file_name': 'img064.jpg'}
# 106 {'height': 720, 'width': 1280, 'id': 106, 'file_name': 'img019.jpg'}
# 107 {'height': 720, 'width': 1280, 'id': 107, 'file_name': 'img045.jpg'}
# 108 {'height': 720, 'width': 1280, 'id': 108, 'file_name': 'img003.jpg'}
# 109 {'height': 720, 'width': 1280, 'id': 109, 'file_name': 'img072.jpg'}
# 110 {'height': 720, 'width': 1280, 'id': 110, 'file_name': 'img011.jpg'}
# 111 {'height': 720, 'width': 1280, 'id': 111, 'file_name': 'img094.jpg'}
# 112 {'height': 720, 'width': 1280, 'id': 112, 'file_name': 'img021.jpg'}
# 113 {'height': 720, 'width': 1280, 'id': 113, 'file_name': 'img083.jpg'}
# 114 {'height': 720, 'width': 1280, 'id': 114, 'file_name': 'img007.jpg'}
# 115 {'height': 720, 'width': 1280, 'id': 115, 'file_name': 'img066.jpg'}
# 116 {'height': 720, 'width': 1280, 'id': 116, 'file_name': 'img063.jpg'}
# 117 {'height': 720, 'width': 1280, 'id': 117, 'file_name': 'img037.jpg'}
# 118 {'height': 720, 'width': 1280, 'id': 118, 'file_name': 'img067.jpg'}
# 119 {'height': 720, 'width': 1280, 'id': 119, 'file_name': 'img089.jpg'}
# 120 {'height': 720, 'width': 1280, 'id': 120, 'file_name': 'img023.jpg'}
# 121 {'height': 720, 'width': 1280, 'id': 121, 'file_name': 'img114.jpg'}
# 122 {'height': 720, 'width': 1280, 'id': 122, 'file_name': 'img052.jpg'}
# 123 {'height': 720, 'width': 1280, 'id': 123, 'file_name': 'img133.jpg'}
# 124 {'height': 720, 'width': 1280, 'id': 124, 'file_name': 'img115.jpg'}
# 125 {'height': 720, 'width': 1280, 'id': 125, 'file_name': 'img126.jpg'}
# 126 {'height': 720, 'width': 1280, 'id': 126, 'file_name': 'img056.jpg'}
# 127 {'height': 720, 'width': 1280, 'id': 127, 'file_name': 'img065.jpg'}
# 128 {'height': 720, 'width': 1280, 'id': 128, 'file_name': 'img075.jpg'}
# 129 {'height': 720, 'width': 1280, 'id': 129, 'file_name': 'img119.jpg'}
# 130 {'height': 720, 'width': 1280, 'id': 130, 'file_name': 'img047.jpg'}
# 131 {'height': 720, 'width': 1280, 'id': 131, 'file_name': 'img100.jpg'}
# 132 {'height': 720, 'width': 1280, 'id': 132, 'file_name': 'img008.jpg'}
# 133 {'height': 720, 'width': 1280, 'id': 133, 'file_name': 'img028.jpg'}
# 134 {'height': 720, 'width': 1280, 'id': 134, 'file_name': 'img059.jpg'}
# 135 {'height': 720, 'width': 1280, 'id': 135, 'file_name': 'img010.jpg'}

# %%
html = coco_dataset.display_image(5, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 720
#   width: 1280
#   id: 5
#   file_name: img098.jpg
#   segmentations (6):
#     22:blue:{'supercategory': 'midlane', 'id': 2, 'name': 'midlane'}
#     23:purple:{'supercategory': 'rightlane', 'id': 4, 'name': 'rightlane'}
#     24:red:{'supercategory': 'pothole', 'id': 3, 'name': 'pothole'}
#     25:green:{'supercategory': 'pothole', 'id': 3, 'name': 'pothole'}
#     26:orange:{'supercategory': 'pothole', 'id': 3, 'name': 'pothole'}
#     27:salmon:{'supercategory': 'pothole', 'id': 3, 'name': 'pothole'}
# <div class="container" style="position:relative;"><img src="roadscene_train/img098.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="337.5"><polygon points=" 69 305 106 307 291 172 294 167 292 166" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="453 269 465 268 321 171 322 172" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="284 241 276 242 274 241 270 240 271 236 275 236 280 235 283 235 287 236
#  287 238" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><polygon points="389 239 385 241 380 241 376 242 373 238 373 236 375 234 377 233 379 233
#  382 233 385 233 388 234 390 236" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0.5" /><polygon points="283 194 282 193 277 193 274 193 271 193 268 193 268 196 271 198 276 198
#  281 198 284 197" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0.5" /><polygon points="277 188 283 188 286 188 289 190 286 191 282 193 274 193 272 192 271 190
#  276 189" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0.5" /><text x="69" y="166" fill="yellow">midlane</text><polygon points=" 69 166 294 166 294 307  69 307  69 166" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="321" y="171" fill="yellow">rightlane</text><polygon points="321 171 465 171 465 269 321 269 321 171" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="270" y="235" fill="yellow">pothole</text><polygon points="270 235 287 235 287 241 270 241 270 235" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /><text x="373" y="232" fill="yellow">pothole</text><polygon points="373 232 390 232 390 242 373 242 373 232" style="fill:green; stroke:green; stroke-width:1; fill-opacity:0" /><text x="268" y="193" fill="yellow">pothole</text><polygon points="268 193 284 193 284 198 268 198 268 193" style="fill:orange; stroke:orange; stroke-width:1; fill-opacity:0" /><text x="271" y="188" fill="yellow">pothole</text><polygon points="271 188 288 188 288 193 271 193 271 188" style="fill:salmon; stroke:salmon; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>

# %%
html = coco_dataset.display_image(1, use_url=False)
IPython.display.HTML(html)
# Out:
# Image:
# ======
#   height: 720
#   width: 1280
#   id: 1
#   file_name: img103.jpg
#   segmentations (3):
#     5:blue:{'supercategory': 'midlane', 'id': 2, 'name': 'midlane'}
#     6:purple:{'supercategory': 'rightlane', 'id': 4, 'name': 'rightlane'}
#     7:red:{'supercategory': 'pothole', 'id': 3, 'name': 'pothole'}
# <div class="container" style="position:relative;"><img src="roadscene_train/img103.jpg" style="position:relative;top:0px;left:0px;width:600px;"><div class="svgclass"><svg width="600" height="337.5"><polygon points=" 65 306 131 306 248 213 287 180 292 172 290 171 285 170 236 203" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0.5" /><polygon points="465 268 479 268 332 173 330 174" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0.5" /><polygon points="281 212 287 204 286 199 284 195 292 189 296 186 301 187 306 189 308 194
#  307 196 306 199 305 203 305 208 306 213 304 219 302 223 296 224 290 224
#  283 224 281 223 280 219" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0.5" /><text x="65" y="170" fill="yellow">midlane</text><polygon points=" 65 170 292 170 292 306  65 306  65 170" style="fill:blue; stroke:blue; stroke-width:1; fill-opacity:0" /><text x="330" y="172" fill="yellow">rightlane</text><polygon points="330 172 479 172 479 268 330 268 330 172" style="fill:purple; stroke:purple; stroke-width:1; fill-opacity:0" /><text x="280" y="186" fill="yellow">pothole</text><polygon points="280 186 308 186 308 224 280 224 280 186" style="fill:red; stroke:red; stroke-width:1; fill-opacity:0" /></svg></div></div><style>.svgclass { position:absolute; top:0px; left:0px;}</style>
